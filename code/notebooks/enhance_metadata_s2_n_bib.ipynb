# %% [markdown]
# ## ACL + Semantic Scholar + .bib enhancements
#
# This notebook will fetch the corpus ids of all ACL docs from semantic scholar.
#
# Some titles and other metadata is not accurately extracted by GROBID, so we are populating those by using the .bib files.
# The following fields are in the final dataframe that we share -
#
# |   **Column name**  |        **Description**        |
# |:------------------:|:-----------------------------:|
# |      `acl_id `     |         unique ACL id         |
# |     `abstract `    |  abstract extracted by GROBID |
# |    `full_text `    | full text extracted by GROBID |
# | `corpus_paper_id ` |      Semantic Scholar ID      |
# |     `pdf_hash `    |      sha1 hash of the pdf     |
# |    `numcitedby `   |  number of citations from S2  |
# |       `url `       |      link of publication      |
# |    `publisher `    |               -               |
# |     `address `     |     Address of conference     |
# |       `year`       |               -               |
# |      `month `      |               -               |
# |    `booktitle `    |               -               |
# |      `author `     |        list of authors        |
# |      `title `      |         title of paper        |
# |      `pages `      |               -               |
# |       `doi `       |               -               |
# |      `number `     |               -               |
# |      `volume `     |               -               |
# |     `journal `     |               -               |
# |      `editor `     |               -               |
# |       `isbn `      |               -               |

# %%
import pandas as pd
from pys2 import (
    _get_redshift_connection,
    _load_dataframe_to_redshift,
)
import glob, os

from tqdm import tqdm
import logging
from urllib.parse import urlparse
logging.basicConfig(level=logging.INFO)
tqdm.pandas()

# %%
df_acl = pd.read_parquet('../../acl_corpus_full-text.parquet')

# %%
df_acl
# Out:
#          acl_id                                              title  \
# 0      O02-2002  A Study on Word Similarity using Context Vecto...
# 1      L02-1310
# 2      R13-1042  Headerless, Quoteless, but not Hopeless? Using...
# 3      W05-0819   Aligning words in English-Hindi parallel corpora
# 4      L02-1309
# ...         ...                                                ...
# 80008  P99-1056  The grapho-phonological system of written Fren...
# 80009  P99-1051  Acquiring Lexical Generalizations from Corpora...
# 80010  P99-1000  Using Aggregation for Selecting Content when G...
# 80011     P99-1
# 80012  P00-1013  Spoken Dialogue Management Using Probabilistic...
#
#                                                 abstract  \
# 0      There is a need to measure word similarity whe...
# 1
# 2      Thread disentanglement is the task of separati...
# 3      In this paper, we describe a word alignment al...
# 4
# ...                                                  ...
# 80008  The processes through which readers evoke ment...
# 80009  This paper examines the extent to which verb d...
# 80010  As co-chairs, we had two particular objectives...
# 80011
# 80012  Spoken dialogue managers have benefited from u...
#
#                                                full_text
# 0      There is a need to measure word similarity whe...
# 1
# 2      Thread disentanglement is the task of separati...
# 3      In this paper, we describe a word alignment al...
# 4
# ...                                                  ...
# 80008  The processes through which readers evoke ment...
# 80009  This paper examines the extent to which verb d...
# 80010  As co-chairs, we had two particular objectives...
# 80011
# 80012  Spoken dialogue managers have benefited from u...
#
# [80013 rows x 4 columns]

# %%
_load_dataframe_to_redshift(df_acl['acl_id'].to_frame(), 'public.temp_acl_ids', create_table=True, write_privileges=True)

# %%
query = f"""SELECT cps.corpus_paper_id, cps.source_id, cps.pdf_hash
                        FROM content_ext.paper_sources as cps 
                        join public.temp_acl_ids as tcs
                        on cps.source_id=tcs.acl_id;"""
df_res = pd.read_sql(query, _get_redshift_connection(write_privileges=True))

# %%
df_res
# Out:
#        corpus_paper_id            source_id  \
# 0             16975984             W13-3727
# 1             17493228             W15-3219
# 2             18918491             H94-1080
# 3            184482972             S19-2116
# 4             13867055             W18-1816
# ...                ...                  ...
# 73940        222134115  2020.emnlp-main.721
# 73941         24010309             L16-1728
# 73942         22286897             F13-1017
# 73943        174802812             P19-1355
# 73944        227231309         2020.msr-1.6
#
#                                        pdf_hash
# 0      eb66e03bea910715f7a82f3600f146a0f2cd022e
# 1      be9615d02d46c1b1fa4521f52b210c245f372281
# 2      583d605b8c632d130e3779af7205066e2ca78d00
# 3      df24ce19ee012bcb642223a430c9ce1fda493220
# 4      87941a5597b950d35e104fde4507ec1215c66366
# ...                                         ...
# 73940  5cda42f13cbb2c4141f41f5f77b83ccd3edf51e9
# 73941  318ecd3da4234962764224909504202eb39e7f11
# 73942  80cc3c263d3fe99aca0b9fa06c544c484df034c1
# 73943  d6a083dad7114f3a39adc65c09bfbb6cf3fee9ea
# 73944  030f8dc426f5f893082bde4d2b7d1aa79188363d
#
# [73945 rows x 3 columns]

# %%
df_papers_acl = df_acl.merge(df_res, left_on='acl_id', right_on='source_id')
df_papers_acl = df_papers_acl.drop(['source_id'], axis=1)

# %%
df_papers_acl.head()
# Out:
#      acl_id                                              title  \
# 0  O02-2002  A Study on Word Similarity using Context Vecto...
# 1  L02-1310
# 2  R13-1042  Headerless, Quoteless, but not Hopeless? Using...
# 3  W05-0819   Aligning words in English-Hindi parallel corpora
# 4  L02-1309
#
#                                             abstract  \
# 0  There is a need to measure word similarity whe...
# 1
# 2  Thread disentanglement is the task of separati...
# 3  In this paper, we describe a word alignment al...
# 4
#
#                                            full_text  corpus_paper_id  \
# 0  There is a need to measure word similarity whe...         18022704
# 1                                                             8220988
# 2  Thread disentanglement is the task of separati...         16703040
# 3  In this paper, we describe a word alignment al...          1215281
# 4                                                            18078432
#
#                                    pdf_hash
# 0  0b09178ac8d17a92f16140365363d8df88c757d0
# 1  8d5e31610bc82c2abc86bc20ceba684c97e66024
# 2  3eb736b17a5acb583b9a9bd99837427753632cdb
# 3  b20450f67116e59d1348fc472cfc09f96e348f55
# 4  011e943b64a78dadc3440674419821ee080f0de3

# %%
_load_dataframe_to_redshift(df_papers_acl['corpus_paper_id'].to_frame(), 'public.temp_acl_ids', create_table=True, write_privileges=True)
# Out:
# /net/nfs2.s2-research/shaurya/sw/miniconda3/envs/s2jupy/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# INFO:pys2:Truncating table public.temp_acl_ids
# INFO:pys2:Loading new data from S3 into public.temp_acl_ids
# INFO:pys2:Done loading public.temp_acl_ids

# %%
query = f"""SELECT DISTINCT cps.corpus_paper_id, numcitedby
                        FROM content_ext.paper_es as cps 
                        join public.temp_acl_ids as tcs
                        on cps.corpus_paper_id=tcs.corpus_paper_id;"""
df_res = pd.read_sql(query, _get_redshift_connection(write_privileges=True))
# Out:
# /net/nfs2.s2-research/shaurya/sw/miniconda3/envs/s2jupy/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df_res = df_res.drop_duplicates()
df_res = df_res.groupby(['corpus_paper_id'], sort=False)['numcitedby'].max().reset_index()

# %% [markdown]
# S2 stores all the citations of the paper over the years. We just need the latest number

# %%
df_papers_acl = df_papers_acl.merge(df_res, on='corpus_paper_id')

# %%
df_papers_acl.head()
# Out:
#      acl_id                                              title  \
# 0  O02-2002  A Study on Word Similarity using Context Vecto...
# 1  L02-1310
# 2  R13-1042  Headerless, Quoteless, but not Hopeless? Using...
# 3  W05-0819   Aligning words in English-Hindi parallel corpora
# 4  L02-1309
#
#                                             abstract  \
# 0  There is a need to measure word similarity whe...
# 1
# 2  Thread disentanglement is the task of separati...
# 3  In this paper, we describe a word alignment al...
# 4
#
#                                            full_text  corpus_paper_id  \
# 0  There is a need to measure word similarity whe...         18022704
# 1                                                             8220988
# 2  Thread disentanglement is the task of separati...         16703040
# 3  In this paper, we describe a word alignment al...          1215281
# 4                                                            18078432
#
#                                    pdf_hash  numcitedby
# 0  0b09178ac8d17a92f16140365363d8df88c757d0          14
# 1  8d5e31610bc82c2abc86bc20ceba684c97e66024          93
# 2  3eb736b17a5acb583b9a9bd99837427753632cdb          10
# 3  b20450f67116e59d1348fc472cfc09f96e348f55          15
# 4  011e943b64a78dadc3440674419821ee080f0de3          12

# %% [markdown]
# # Adding missing titles, years and abstracts from .bib

# %%
import bibtexparser

list_acl_bib = []
for file in tqdm(glob.glob('ACL/bib/*.bib')):
    with open(file) as bibtex_file:
        bib_database = bibtexparser.load(bibtex_file)
        try:
            _dict =  bib_database.entries[0]
            _dict['acl_id'] = os.path.basename(file)[:-4]
            list_acl_bib.append(_dict)
        except:
            continue
df_bib = pd.DataFrame(list_acl_bib)
# Out:
# 100%|██████████| 80014/80014 [14:14<00:00, 93.59it/s]

# %%
df_bib.head()
# Out:
#                                                  url  \
# 0  http://www.lrec-conf.org/proceedings/lrec2004/...
# 1                  https://aclanthology.org/D19-5024
# 2                  https://aclanthology.org/P82-1017
# 3        https://aclanthology.org/2020.emnlp-main.50
# 4                  https://aclanthology.org/C80-1091
#
#                                         publisher                   address  \
# 0  European Language Resources Association (ELRA)          Lisbon, Portugal
# 1       Association for Computational Linguistics          Hong Kong, China
# 2       Association for Computational Linguistics  Toronto, Ontario, Canada
# 3       Association for Computational Linguistics                    Online
# 4                                             NaN                       NaN
#
#    year     month                                          booktitle  \
# 0  2004       May  Proceedings of the Fourth International Confer...
# 1  2019  November  Proceedings of the Second Workshop on Natural ...
# 2  1982      June  20th Annual Meeting of the Association for Com...
# 3  2020  November  Proceedings of the 2020 Conference on Empirica...
# 4  1980       NaN  {COLING} 1980 Volume 1: The 8th International ...
#
#                                               author  \
# 0  Traum, David R.  and\nRobinson, Susan  and\nSt...
# 1  Da San Martino, Giovanni  and\nBarr{\'o}n-Cede...
# 2                                  Walker, Donald E.
# 3  Li, Manling  and\nZeng, Qi  and\nLin, Ying  an...
# 4                                     Tuldava, Juhan
#
#                                                title      ENTRYTYPE  \
# 0  Evaluation of Multi-party Virtual Reality Dial...  inproceedings
# 1  Findings of the {NLP}4{IF}-2019 Shared Task on...  inproceedings
# 2  Reflections on 20 Years of the {ACL}: An Intro...  inproceedings
# 3  Connecting the Dots: Event Graph Schema Induct...  inproceedings
# 4  A Mathematical Model of the Vocabulary-Text Re...  inproceedings
#
#                                   ID  ...  \
# 0         traum-etal-2004-evaluation  ...
# 1  da-san-martino-etal-2019-findings  ...
# 2            walker-1982-reflections  ...
# 3            li-etal-2020-connecting  ...
# 4          tuldava-1980-mathematical  ...
#
#                                             abstract     pages  \
# 0                                                NaN       NaN
# 1  We present the shared task on Fine-Grained Pro...  162--170
# 2                                                NaN    89--91
# 3  Event schemas can guide our understanding and ...  684--695
# 4                                                NaN       NaN
#
#                               doi number volume journal editor isbn language  \
# 0                             NaN    NaN    NaN     NaN    NaN  NaN      NaN
# 1            10.18653/v1/D19-5024    NaN    NaN     NaN    NaN  NaN      NaN
# 2           10.3115/981251.981273    NaN    NaN     NaN    NaN  NaN      NaN
# 3  10.18653/v1/2020.emnlp-main.50    NaN    NaN     NaN    NaN  NaN      NaN
# 4                             NaN    NaN    NaN     NaN    NaN  NaN      NaN
#
#   note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 21 columns]

# %%
df_papers_acl = df_papers_acl.merge(df_bib, on='acl_id')

# %%
df_papers_acl = df_papers_acl.drop(['title_x', 'abstract_y', 'ENTRYTYPE', 'ID', 'language', 'note'], axis=1)

# %%
df_papers_acl = df_papers_acl.rename(columns={"title_y": "title", "abstract_x": "abstract"})

# %%
df_papers_acl.columns
# Out:
# Index(['acl_id', 'abstract', 'full_text', 'corpus_paper_id', 'pdf_hash',
#        'numcitedby', 'url', 'publisher', 'address', 'year', 'month',
#        'booktitle', 'author', 'title', 'pages', 'doi', 'number', 'volume',
#        'journal', 'editor', 'isbn'],
#       dtype='object')

# %%
df_papers_acl.head()
# Out:
#      acl_id                                           abstract  \
# 0  O02-2002  There is a need to measure word similarity whe...
# 1  L02-1310
# 2  R13-1042  Thread disentanglement is the task of separati...
# 3  W05-0819  In this paper, we describe a word alignment al...
# 4  L02-1309
#
#                                            full_text  corpus_paper_id  \
# 0  There is a need to measure word similarity whe...         18022704
# 1                                                             8220988
# 2  Thread disentanglement is the task of separati...         16703040
# 3  In this paper, we describe a word alignment al...          1215281
# 4                                                            18078432
#
#                                    pdf_hash  numcitedby  \
# 0  0b09178ac8d17a92f16140365363d8df88c757d0          14
# 1  8d5e31610bc82c2abc86bc20ceba684c97e66024          93
# 2  3eb736b17a5acb583b9a9bd99837427753632cdb          10
# 3  b20450f67116e59d1348fc472cfc09f96e348f55          15
# 4  011e943b64a78dadc3440674419821ee080f0de3          12
#
#                                                  url  \
# 0                  https://aclanthology.org/O02-2002
# 1  http://www.lrec-conf.org/proceedings/lrec2002/...
# 2                  https://aclanthology.org/R13-1042
# 3                  https://aclanthology.org/W05-0819
# 4  http://www.lrec-conf.org/proceedings/lrec2002/...
#
#                                         publisher  \
# 0                                             NaN
# 1  European Language Resources Association (ELRA)
# 2                   INCOMA Ltd. Shoumen, BULGARIA
# 3       Association for Computational Linguistics
# 4  European Language Resources Association (ELRA)
#
#                               address  year  ...  \
# 0                                 NaN  2002  ...
# 1  Las Palmas, Canary Islands - Spain  2002  ...
# 2                    Hissar, Bulgaria  2013  ...
# 3                 Ann Arbor, Michigan  2005  ...
# 4  Las Palmas, Canary Islands - Spain  2002  ...
#
#                                            booktitle  \
# 0  International Journal of Computational Linguis...
# 1  Proceedings of the Third International Confere...
# 2  Proceedings of the International Conference Re...
# 3  Proceedings of the {ACL} Workshop on Building ...
# 4  Proceedings of the Third International Confere...
#
#                                               author  \
# 0                Chen, Keh-Jiann  and\nYou, Jia-Ming
# 1                                  Mihalcea, Rada F.
# 2               Jamison, Emily  and\nGurevych, Iryna
# 3             Aswani, Niraj  and\nGaizauskas, Robert
# 4  Suyaga, Fumiaki  and\nTakezawa, Toshiyuki  and...
#
#                                                title     pages  doi number  \
# 0  A Study on Word Similarity using Context Vecto...    37--58  NaN    NaN
# 1           Bootstrapping Large Sense Tagged Corpora       NaN  NaN    NaN
# 2  Headerless, Quoteless, but not Hopeless? Using...  327--335  NaN    NaN
# 3  Aligning Words in {E}nglish-{H}indi Parallel C...  115--118  NaN    NaN
# 4  Proposal of a very-large-corpus acquisition me...       NaN  NaN    NaN
#
#   volume journal editor isbn
# 0    NaN     NaN    NaN  NaN
# 1    NaN     NaN    NaN  NaN
# 2    NaN     NaN    NaN  NaN
# 3    NaN     NaN    NaN  NaN
# 4    NaN     NaN    NaN  NaN
#
# [5 rows x 21 columns]

# %%
df_papers_acl.to_parquet('acl-publication-info.74k.parquet', compression='gzip')
